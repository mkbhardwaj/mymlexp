# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import scipy as scipy
import statistics as statistic

# %%
excel_data = pd.read_excel('statistic_data.xlsx')
# Out:
# /Users/mayank/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
excel_data
# Out:
#     Unnamed: 0 365 DataScience RE California Database Unnamed: 2  \
# 0          NaN                      Practical example        NaN
# 1          NaN                                    NaN        NaN
# 2          NaN                                Product        NaN
# 3          NaN                                     ID   Building
# 4          NaN                                   1030          1
# ..         ...                                    ...        ...
# 266        NaN                                   5044          5
# 267        NaN                                   5047          5
# 268        NaN                                   5048          5
# 269        NaN                                   5050          5
# 270        NaN                                   5051          5
#
#        Unnamed: 3     Unnamed: 4        Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0             NaN            NaN               NaN         NaN         NaN
# ...
