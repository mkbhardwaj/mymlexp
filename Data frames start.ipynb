# %%
import pandas as pd
import os

# %%
# Method 1 : use full path (in the windows we have to metion like c:\\mayank\..)
dataFrame = pd.read_csv('/Users/mayank/Projects/Jupyter/P4-Demographic-Data.csv')

# %%
dataFrame
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#meothod 2 : change the working directory
print(os.getcwd())
# we can change the working directory as well, how ?
os.chdir('/Users/mayank/Projects/Jupyter')
stats = pd.read_csv('P4-Demographic-Data.csv')
# Out:
# /Users/mayank/Projects/Jupyter

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Exploring the data 
# 1. check all the data -- print the data directly
# 2. check the number of rows - len function 
# 3. see the columns
# 4. number of the columns 
# 5. head rows - head() -- top
# 6. bottom rows - tail() -- bottom
# 7. get information about the columns - info()
# 8. get stats on the columns -> describe()
len(stats)
# Out:
# 195

# %%
print(stats.columns)
print(len(stats.columns))
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')
# 5

# %%
stats.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
stats.tail(10)
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
# Subsetting dataframes in Pandas  
# -- Rows - slicing [start : end : step]
# -- Columns - how to select only few colums out of all stats[['column_name','column_name2']]
# -- Combine the two
# -- reverse a list or data frame = [::-1]

# %%
stats.columns = ['Country_Name','Country_Code','Birth_Rate',\
'Internet_Users','Income_Group']

# %%
stats[:4][['Country_Name', 'Birth_Rate', 'Income_Group']] # slicing for the rows and for columns pass a list
# Out:
#   Country_Name  Birth_Rate         Income_Group
# 0        Aruba      10.244          High income
# 1  Afghanistan      35.253           Low income
# 2       Angola      45.985  Upper middle income
# 3      Albania      12.877  Upper middle income

# %%
stats['New Col'] = stats.Birth_Rate * stats.Internet_Users

# %%
stats
# Out:
#              Country_Name Country_Code  Birth_Rate  Internet_Users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income_Group   New Col
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# ...

# %%
# remove the column 
stats = stats.drop('New Col', 1) # axis 0: Row, 1: Column

# %%
stats
# Out:
#              Country_Name Country_Code  Birth_Rate  Internet_Users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income_Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Filtering the rows 
stats[stats.Internet_Users < 2]
# Out:
#      Country_Name Country_Code  Birth_Rate  Internet_Users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income_Group
# 11            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 117  Lower middle income
# 127           Low income
# 154           Low income
# 156           Low income
# 172  Lower middle income

# %%
# combining multiple filters 
# can't use the and as it won't support series operation
# so we will use &
stats[(stats.Internet_Users < 2) & (stats.Birth_Rate < 40)]
# Out:
#      Country_Name Country_Code  Birth_Rate  Internet_Users  \
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 154  Sierra Leone          SLE      36.729             1.7
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income_Group
# 52            Low income
# 55            Low income
# 64            Low income
# 117  Lower middle income
# 154           Low income
# 172  Lower middle income

# %%
# unique values 
stats.Income_Group.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats[stats.Country_Name == 'Malta']
# Out:
#     Country_Name Country_Code  Birth_Rate  Internet_Users Income_Group
# 116        Malta          MLT         9.5         68.9138  High income

# %%
stats['Country_Name'][10]
# Out:
# 'Azerbaijan'

# %%
# access individual statement 
# at: for labels. Evne intergers are treated as labels
# iat: for interger location
stats.iat[3,0]
# Out:
# 'Albania'

# %%
stats.at[3, 'Country_Name']
# Out:
# 'Albania'

# %%
stats.head(10)
# Out:
#            Country_Name Country_Code  Birth_Rate  Internet_Users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income_Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %% [markdown]
# # why at is even required ?
# # at will always give us values as label not by counting

# %%
import matplotlib.pyplot as plt 
import seaborn as sns # another visualization library based out of matplot 
# to print the graph inline 
# %matplotlib inline  
# increase the chart size in output 
plt.rcParams['figure.figsize'] =  8,6

# %%
#Distribution
vis1 = sns.distplot(stats['Internet_Users'], bins = 30)
# Out:
# /Users/mayank/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
vis2 = sns.boxplot(data = stats, x = 'Income_Group', y = 'Birth_Rate')

# %%
vis3 = sns.lmplot(x = "Internet_Users", y = "Birth_Rate", data = stats, hue = "Income_Group",\
                  fit_reg = False, height = 7,  scatter_kws = {'s': 30})
